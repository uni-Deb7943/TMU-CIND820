# %% [markdown]
# # Initial Results and Code
#
# This document compiles the technical notebooks for the CIND820 - Big Data Analytics Project on Commercial Property Fire-Peril Loss Cost Modelling.

# %% [markdown]
# ## 1. Exploratory Data Analysis
# See Notebook: 01_EDA_and_Data_Analysis.ipynb
#
# ## 2. Data Preparation
# See Notebook: 02_Data_Preparation.ipynb
#
# ## 3. Tweedie GLM Model
# See Notebook: 03_Tweedie_GLM.ipynb
#
# ## 4. Gradient Boosting Model
# See Notebook: 04_Gradient_Boosting_Model.ipynb
#
# ## 5. Model Comparison: Tweedie GLM vs Gradient Boosting
# See Notebook: 05_Model_Comparison.ipynb
